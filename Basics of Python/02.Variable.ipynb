# %%
# Defination of a variable?

# %%
# Data can be stored in temporary storage spaces called variables.

# %%
# Every variable has name and address.

# %%
# Vriables are declared without Data Types.

# %%
# First letter cannot be a digit.

# %%
# Variables are case sensitive.

# %%
#Usage:-
# No space.
# Lowercase.
# No usage of the special character.
# Only use the underscore special character ( _ ).
