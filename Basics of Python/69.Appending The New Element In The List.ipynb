# %%
# Appending The New Element is the list:-

# %%
# we can append the new element in the list  by using the function { List Identifier.append ( --- ) }.

# %%
# ( ---- ) is the new heterogenous element to be add as the new element.
