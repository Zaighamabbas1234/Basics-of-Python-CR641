# %%
# Tuple:-

# %%
# Tuple is an ordered collection of elements enclose within brackets ( ).

# %%
# Hetrogenous elements (Int, float, boolean , character) can saved in a tuple.

# %%
# Tuple are immutable. ( Cannot be changed. )
# Do not allow replacing of the subtuple.
