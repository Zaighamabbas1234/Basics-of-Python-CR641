# %%
tuple_1 = (4,5,6,1.4,1.8,1.9,True,False)

# %%
print(tuple_1)
# Out:
# (4, 5, 6, 1.4, 1.8, 1.9, True, False)

# %%
tuple_2 = (0,1,2,3,4,5,6,False,True)

# %%
print(tuple_2)
# Out:
# (0, 1, 2, 3, 4, 5, 6, False, True)

# %%
print(tuple_1*2)
# Out:
# (4, 5, 6, 1.4, 1.8, 1.9, True, False, 4, 5, 6, 1.4, 1.8, 1.9, True, False)

# %%
print(tuple_2*3)
# Out:
# (0, 1, 2, 3, 4, 5, 6, False, True, 0, 1, 2, 3, 4, 5, 6, False, True, 0, 1, 2, 3, 4, 5, 6, False, True)

# %%
print(tuple_1+tuple_2)
# Out:
# (4, 5, 6, 1.4, 1.8, 1.9, True, False, 0, 1, 2, 3, 4, 5, 6, False, True)

# %%
print(tuple_2*2+tuple_1)
# Out:
# (0, 1, 2, 3, 4, 5, 6, False, True, 0, 1, 2, 3, 4, 5, 6, False, True, 4, 5, 6, 1.4, 1.8, 1.9, True, False)
