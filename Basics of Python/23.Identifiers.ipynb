# %%
# Identifers:-

# %%
# Identifers are the names used for the function, variables and objects.

# %%
# No special character except underscore ( _ ).

# %%
# Identifiers are case sensitive.

# %%
# First letter cannot be a digit.
