# %%
# Index of a Substring:-

# %%
# To find the index of a substring we use the function -----.find ( "-----" ).

# %%
# ----- is the string name.

# %%
# ( " ----- " ) is the word or alphabet to be find.
