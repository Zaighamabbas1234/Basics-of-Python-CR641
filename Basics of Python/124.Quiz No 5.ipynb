# %%
# Quiz No 5:-

# %%
# Write a python program that prints the number from 1 to n using a while loop?

# %%
# Solution:-

# %%
number = int(input("Enter the number?"))

# %%
print(number)
# Out:
# 5

# %%
i = 1

# %%
while (i <= number):
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5
