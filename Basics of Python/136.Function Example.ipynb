# %%
length = int(input("Enter the length of the triangle."))

# %%
print(length)
# Out:
# 10

# %%
width = int(input("Enter the width if the triangle."))

# %%
print(width)
# Out:
# 20

# %%
def calculate_area (length,width):
    area = length*width
    return area

# %%
print(calculate_area (length,width))
# Out:
# 200
