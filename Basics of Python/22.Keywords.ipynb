# %%
# Defination of Keywords:-

# %%
# Keywords are special reserved words.
# 32 keywords in python.

# %%
# Cannot be used as function and class and variables.

# %%
# Variables Names:-

# %%
# 1) false.

# %%
# 2) none.

# %%
# 3) true.

# %%
# 4) and.

# %%
# 5) as.

# %%
# 6) class.

# %%
# 7) continue.

# %%
# 8) def.

# %%
# 9) del.

# %%
# 10) elif.

# %%
# 11) finally.

# %%
# 12) for.

# %%
# 13) global.

# %%
# 14) if.

# %%
# 15) from.

# %%
# 16) is.

# %%
# 17) not.

# %%
# 18) or.

# %%
# 19) lambda.

# %%
# 20) notlocal.

# %%
# 21) return.

# %%
# 22) try.

# %%
# 23) while.

# %%
# 24) with.

# %%
# 25) yield.
