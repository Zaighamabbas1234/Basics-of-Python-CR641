# %%
set ={ "Set",False,"Data",1,2,3,4}

# %%
print(set)
# Out:
# {False, 1, 2, 3, 4, 'Set', 'Data'}

# %%
# Removing an element in the set:-

# %%
# Use the following function set identifier.eremove( Elemert an character ).

# %%
set.remove("Set")

# %%
print(set)
# Out:
# {False, 1, 2, 3, 4, 'Data'}

# %%
# Add an set elment in the set.
# For this we will use the function set identifer.add( Digit or Character ).

# %%
set.add(10) # Print the output in the random order.

# %%
print(set)
# Out:
# {False, 1, 2, 3, 4, 'Data', 10}

# %%
# Updating the multiple elements in the set.
# For this use the function set identifer.update ( [ ] ).
# Always use the following ( [ ] ).

# %%
set.update([100,200,300,400])

# %%
print(set)
# Out:
# {False, 1, 2, 3, 4, 200, 10, 400, 100, 300, 'Data'}
