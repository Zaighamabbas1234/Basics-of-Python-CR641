# %%
str = "This is spartaa."

# %%
print(str)
# Out:
# This is spartaa.

# %%
# For Acending Order:-

# %%
str[0]
# Out:
# 'T'

# %%
str[1]
# Out:
# 'h'

# %%
str[2]
# Out:
# 'i'

# %%
str[3]
# Out:
# 's'

# %%
str[4] # This shows the space.
# Out:
# ' '

# %%
str[5]
# Out:
# 'i'

# %%
str[6]
# Out:
# 's'

# %%
str[7]
# Out:
# ' '

# %%
str[8]
# Out:
# 's'

# %%
str[9]
# Out:
# 'p'

# %%
str[10]
# Out:
# 'a'

# %%
str[11]
# Out:
# 'r'

# %%
str[12]
# Out:
# 't'

# %%
str[13]
# Out:
# 'a'

# %%
str[14]
# Out:
# 'a'

# %%
str[15]
# Out:
# '.'

# %%
# For Decending order:-

# %%
# 0 is always positive hence in decending order it is alwasy starts from the 1.

# %%
str[-1]
# Out:
# '.'

# %%
str[-2]
# Out:
# 'a'

# %%
str[-3]
# Out:
# 'a'

# %%
str[-4]
# Out:
# 't'

# %%
str[-5]
# Out:
# 'r'

# %%
str[-6]
# Out:
# 'a'

# %%
str[-7]
# Out:
# 'p'

# %%
str[-8]
# Out:
# 's'

# %%
str[-9]
# Out:
# ' '

# %%
str[-10]
# Out:
# 's'

# %%
str[-11]
# Out:
# 'i'

# %%
str[-12]
# Out:
# ' '

# %%
str[-13]
# Out:
# 's'

# %%
str[-14]
# Out:
# 'i'

# %%
str[-15]
# Out:
# 'h'

# %%
str[-16]
# Out:
# 'T'
