# %%
list_1 = ['Red','Blue','Green','Pink']

# %%
list_2 = ['Laptop','Book','Flag','Handkerchieff']

# %%
for i in list_1:
    for j in list_2:
        print(i,j)
# Out:
# Red Laptop
# Red Book
# Red Flag
# Red Handkerchieff
# Blue Laptop
# Blue Book
# Blue Flag
# Blue Handkerchieff
# Green Laptop
# Green Book
# Green Flag
# Green Handkerchieff
# Pink Laptop
# Pink Book
# Pink Flag
# Pink Handkerchieff
