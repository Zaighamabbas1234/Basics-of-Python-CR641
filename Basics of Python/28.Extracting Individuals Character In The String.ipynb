# %%
# Extracting The Individuals Character In The String:-

# %%
# For extracting the individulas character in the string use the indexing.

# %%
# In python the indexing starts form the [ 0 ].
# The index start from the zero.

# %%
# Always use the square bracket.
