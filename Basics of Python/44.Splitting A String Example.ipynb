# %%
str = ("Apple,Banana,Apple,Banana,Gava,Carrort,Patateo,Apple")

# %%
print(str)
# Out:
# Apple,Banana,Apple,Banana,Gava,Carrort,Patateo,Apple

# %%
str.split("e")
# Out:
# ['Appl', ',Banana,Appl', ',Banana,Gava,Carrort,Patat', 'o,Appl', '']

# %%
str.split("a")
# Out:
# ['Apple,B',
#  'n',
#  'n',
#  ',Apple,B',
#  'n',
#  'n',
#  ',G',
#  'v',
#  ',C',
#  'rrort,P',
#  't',
#  'teo,Apple']

# %%
str.split(",")
# Out:
# ['Apple', 'Banana', 'Apple', 'Banana', 'Gava', 'Carrort', 'Patateo', 'Apple']
