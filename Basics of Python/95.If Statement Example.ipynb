# %%
number_1 = int(input("Enter the number."))

# %%
print(number_1)
# Out:
# 10

# %%
number_2 = int(input("Enter the number."))

# %%
print(number_2)
# Out:
# 20

# %%
if (number_1 > number_2):
    print("number_1 is the maximun value.")
elif (number_2 > number_1):
    print("number_2 is the maximum value.")
else:
    print("Both numbers are equal.")
# Out:
# number_2 is the maximum value.
