# %%
a = 10

# %%
b = 20

# %%
# Addition:-

# %%
print(a+b)
# Out:
# 30

# %%
# Subtratction:-

# %%
print(a-b)
# Out:
# -10

# %%
# Multiplication:-

# %%
print(a*b)
# Out:
# 200

# %%
# Division:-

# %%
print(a/b) 
# For answer in Float.
# Out:
# 0.5

# %%
print(a//b) 
# For answer in Integer.
# Out:
# 0
