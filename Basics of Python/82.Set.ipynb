# %%
# Set:-

# %%
# Set is an unordered and unindexded collection of elements enclosed with in the { }.

# %%
# Duplicates are not allowed in sets.

# %%
# A set is mutable.

# %%
# Adding elements in a sequence but the output will not follow any sequence it will print in random order.
# Hence we will not follow the index in the set for adding the new elments in the set.
