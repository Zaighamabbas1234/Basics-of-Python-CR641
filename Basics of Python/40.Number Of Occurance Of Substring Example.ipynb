# %%
str = ("Apple,Banana,Apple,Banana,Gava,Carrort,Patateo,Apple")

# %%
print(str)
# Out:
# Apple,Banana,Apple,Banana,Gava,Carrort,Patateo,Apple

# %%
str.count("Apple")
# Out:
# 3

# %%
str.count("Banana")
# Out:
# 2

# %%
str.count("e")
# Out:
# 4
