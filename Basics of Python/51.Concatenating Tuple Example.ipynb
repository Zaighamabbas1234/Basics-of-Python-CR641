# %%
tuple_1 = (1,2,3,False)

# %%
tuple_2 = (1,2,3,"a,b,c")

# %%
print(tuple_1)
# Out:
# (1, 2, 3, False)

# %%
print(tuple_2)
# Out:
# (1, 2, 3, 'a,b,c')

# %%
print(tuple_1 + tuple_2)
# Out:
# (1, 2, 3, False, 1, 2, 3, 'a,b,c')
