# %%
# Quiz No 1:-

# %%
# Write a python program to concatenate the two strings.

# %%
# Solution:-

# %%
str_1 = ("This is sparta.")

# %%
str_2 = ("My name is Sam.")

# %%
print(str_1,str_2)
# Out:
# This is sparta. My name is Sam.

# %%
print(str_1+str_2)
# Out:
# This is sparta.My name is Sam.
