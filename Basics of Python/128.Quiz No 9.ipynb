# %%
# Quiz No 9:-

# %%
# Write a python program that prints the elements of a list using for loop?

# %%
# Solution:-

# %%
fruits = ['Apple','Banana','Mangeo','Pineapple']

# %%
print(fruits)
# Out:
# ['Apple', 'Banana', 'Mangeo', 'Pineapple']

# %%
for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Banana
# Mangeo
# Pineapple
