# %%
# For the intersection of the two sets use the function (set_1).union(set_2).

# %%
set_1 = {1,2,3,4,5,6,7,8,10}

# %%
set_2 = {2,4,6,8,10,12,14,16}

# %%
print(set_1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 10}

# %%
print(set_2)
# Out:
# {2, 4, 6, 8, 10, 12, 14, 16}

# %%
(set_1).intersection(set_2)
# Out:
# {2, 4, 6, 8, 10}
