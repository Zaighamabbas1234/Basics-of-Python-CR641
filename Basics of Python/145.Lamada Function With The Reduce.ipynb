# %%
list_1 = [1,2,3,4,5,6,7,8]
print(list_1)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
from functools import reduce
# We will need to import this function.
# This will be used to reduce the sequence to find out a concellidate result.

# %%
sum = (reduce(lambda x,y: (x+y) , list_1))

# %%
sum
# Out:
# 36
