# %%
# Operators:-

# %%
# With the help of the operators you can appply differnet operations on the different data.

# %%
# Types of the Operators:-

# %%
# Arithmetic Operators:- ( + , _ , * , / )

# %%
# Relational Operators:- ( < , > , <= , >= , == , != )

# %%
#  Logical Operators:-  ( $ , | )
