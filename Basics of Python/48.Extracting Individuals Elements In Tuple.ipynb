# %%
# Already Explained in previous.

# %%
tuple = (4,5,6,1.4,1.8,1.9,"Data,Data 1,Data 2",True,False)

# %%
print(tuple)
# Out:
# (4, 5, 6, 1.4, 1.8, 1.9, 'Data,Data 1,Data 2', True, False)

# %%
tuple[0]
# Out:
# 4

# %%
tuple[8]
# Out:
# False

# %%
tuple[-5]
# Out:
# 1.8

# %%
tuple[-3]
# Take the string as an one element.
# Out:
# 'Data,Data 1,Data 2'

# %%
tuple[3:7]
# Out:
# (1.4, 1.8, 1.9, 'Data,Data 1,Data 2')
