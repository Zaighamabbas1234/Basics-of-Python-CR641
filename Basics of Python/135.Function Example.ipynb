# %%
def even_odd(x):
    if (x % 2 == 0):
        print("The number is the even.")
    else:
        print("The number is the odd.")

# %%
even_odd(9)
# Out:
# The number is the odd.

# %%
even_odd(50)
# Out:
# The number is the even.
