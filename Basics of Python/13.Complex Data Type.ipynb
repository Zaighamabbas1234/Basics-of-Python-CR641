# %%
x = 4+5j

# %%
# Information:-
# The i is reprezented by j in python.
# 4 = Real Part.
# 5j = Imaginary Part.

# %%
print(x)
# Out:
# (4+5j)

# %%
# How to check the Data Type:-

# %%
type(x)
# Out:
# complex
