# %%
dictionary = {"Apple":10,"Banana":20,"Gava":30,"Pineapple":40}

# %%
print(dictionary)
# Out:
# {'Apple': 10, 'Banana': 20, 'Gava': 30, 'Pineapple': 40}

# %%
# How to cheak the data type:-
# Already explained.

# %%
print(type(dictionary))
# Out:
# <class 'dict'>

# %%
# How to modify the dictionary.
# Adding the new element in the dictionary.
# Already explaind in previous same as the list.

# %%
dictionary["Mangeo"] = 100

# %%
print(dictionary)
# Out:
# {'Apple': 10, 'Banana': 20, 'Gava': 30, 'Pineapple': 40, 'Mangeo': 100}

# %%
# Changing an existing element in the dictionary:-

# %%
dictionary["Apple"] = 100

# %%
print(dictionary)
# Out:
# {'Apple': 100, 'Banana': 20, 'Gava': 30, 'Pineapple': 40, 'Mangeo': 100}

# %%
# Appending the dictionaries.

# %%
dict_1 = { "Apple":10, "Banana":20, "Gava":30, "Pineapple":40}
dict_2 = { 2:"Sam", 3:"Jhon", 4:"Mat", 5:"Alee"}

# %%
# A little bit changing in it we will use the function 
# Dictionary Identifier.update ( Dictionary Identifier).

# %%
dict_1.update(dict_2)

# %%
print(dict_1)
# Out:
# {'Apple': 10, 'Banana': 20, 'Gava': 30, 'Pineapple': 40, 2: 'Sam', 3: 'Jhon', 4: 'Mat', 5: 'Alee'}

# %%
# Poping the dictionary elements.

# %%
dict_1.pop("Apple") # Removing the keys.
# Always use the keys in the ( ).
# Out:
# 10

# %%
print(dict_1)
# Out:
# {'Banana': 20, 'Gava': 30, 'Pineapple': 40, 2: 'Sam', 3: 'Jhon', 4: 'Mat', 5: 'Alee'}
