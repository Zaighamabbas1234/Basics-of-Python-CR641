# %%
a = 10

# %%
b = 20

# %%
# Greator than:-

# %%
print(a>b)
# Out:
# False

# %%
# Less than:-

# %%
print(a<b)
# Out:
# True

# %%
# Less than Equal too:-

# %%
print(a<=b)
# Out:
# True

# %%
# Greator than Equal too:-

# %%
print(a>=b)
# Out:
# False

# %%
# Is Equal too:-

# %%
print(a==b)
# Out:
# False

# %%
# Not Equal too:-

# %%
print(a!=b)
# Out:
# True
