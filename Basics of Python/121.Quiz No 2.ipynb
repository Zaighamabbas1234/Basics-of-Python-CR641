# %%
# Quiz No 2:-

# %%
# Write a program that cheaks if a student is eligible to vote based on their age?

# %%
# Solution:-

# %%
age = int(input("Please enter the age?"))

# %%
print(age)
# Out:
# 10

# %%
if (age>=18):
    print("The candiate is eligible for the vote.")
else:
    print("The canidate is not eligile for the vote.")
# Out:
# The canidate is not eligile for the vote.
