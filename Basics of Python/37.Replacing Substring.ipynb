# %%
# Replacing a substring:-

# %%
# We can replace a string by using the function -----.replace( "a" , "b" ).

# %%
# ----- is the string name.

# %%
# a is the character which you want to replace.

# %%
# b is the character which is used to be replaced by a.

# %%
# Always use () parathensis.
