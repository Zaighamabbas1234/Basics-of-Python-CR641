# %%
# Quiz No 8:-

# %%
# Write a python program that prints the maltiplication table of a a given number uding a while loop?

# %%
# Solution:-

# %%
number = int(input("Enter the number?"))

# %%
print(number)
# Out:
# 10

# %%
i = 1

# %%
while (i<=10):
    print(f"{number}*{i} = {number*i}")
    i = i+1
# Out:
# 10*1 = 10
# 10*2 = 20
# 10*3 = 30
# 10*4 = 40
# 10*5 = 50
# 10*6 = 60
# 10*7 = 70
# 10*8 = 80
# 10*9 = 90
# 10*10 = 100
