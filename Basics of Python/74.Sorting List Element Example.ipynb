# %%
list = [1,2,3,4,5,6,1.123,1.1] # Not support the instances of the string in the list.

# %%
print(list)
# Out:
# [1, 2, 3, 4, 5, 6, 1.123, 1.1]

# %%
list.sort()

# %%
print(list)
# Out:
# [1, 1.1, 1.123, 2, 3, 4, 5, 6]
