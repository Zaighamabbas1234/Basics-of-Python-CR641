# %%
fruits = ["Apple","Banana","Gava","Pineapple"]

# %%
print(fruits)
# Out:
# ['Apple', 'Banana', 'Gava', 'Pineapple']

# %%
for index, fruits in enumerate(fruits):
    print(f"{index}:{fruits}")
# Out:
# 0:Apple
# 1:Banana
# 2:Gava
# 3:Pineapple
