# %%
# Python Tokens:-

# %%
# Smallest meaningfull component in a program is called Python Token.

# %%
# Types of Python Tokens:-

# %%
# Keywords.

# %%
# Identifiers.

# %%
# Literals.

# %%
# Operators. (Already Done.)
