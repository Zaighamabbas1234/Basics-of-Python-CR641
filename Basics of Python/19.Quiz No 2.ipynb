# %%
# Quiz No 2:-

# %%
# Declare the integer variable x with the value 25.
# Declare the float variable y with the value 25.5.
# Declare the string variable z with the value "Hello".
# Print all the varibales.

# %%
# Solution:

# %%
x = 25

# %%
y = 25.5

# %%
z = "Hello"

# %%
print(x)
# Out:
# 25

# %%
type (x)
# Out:
# int

# %%
print(y)
# Out:
# 25.5

# %%
type (y)
# Out:
# float

# %%
print(z)
# Out:
# Hello

# %%
type (z)
# Out:
# str
