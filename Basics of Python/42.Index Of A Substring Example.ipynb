# %%
str = "The quick lazy fox jumps over the lazy dog."

# %%
print(str)
# Out:
# The quick lazy fox jumps over the lazy dog.

# %%
str.find("lazy")
# Out:
# 10

# %%
str.find("jumps")
# Out:
# 19

# %%
str.find ("e")
# Out:
# 2
