# %%
# Looping:-

# %%
# Looping statements are used to repeat a task multiple times.

# %%
# Examples:-

# %%
# Filling the bucket with a mug of water while it is not full.

# %%
# Keep repeating the song until you close the app.

# %%
# Get your salary credited at the end of the month.
