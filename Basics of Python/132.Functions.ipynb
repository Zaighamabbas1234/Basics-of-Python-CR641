# %%
# Functions:-

# %%
# Function is a block of code which performs specific tasks.

# %%
# Multiple things involved in it.

# %%
# Exapmle:-
# Eating.
# Cycling.
# Runing.
# ATM.

# %%
# ATM Example:-
# Deposite:-............................Function to deposite the money.
# Balance:..............................Function to cheak the balance.
# Withdraw:-............................Function to withdraw the money.

# %%
# To define a function we use the keyword def (Defination).
