# %%
# Quiz No 1:-

# %%
# Write a program that cheaks if a number is positive, negative and zero?

# %%
# Solution:-

# %%
number = int(input("Please enter the number?"))

# %%
print(number)
# Out:
# 20

# %%
if (number>0):
    print("This is a positive number.")
elif (number<0):
    print("This is the nagative number.")
else:
    print("This is zero.")
# Out:
# This is a positive number.
