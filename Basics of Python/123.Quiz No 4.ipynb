# %%
# Quiz No 2:-

# %%
# Write a python program that cheaks if a person is eligible for the dicount based on their age?

# %%
# Solution:-

# %%
age = int(input("Please enter the age?"))

# %%
print(age)
# Out:
# 50

# %%
if (age>=60):
    print("The canidiate is eligible for the citizen discount.")
elif (age<18):
    print("The canidiate is eligible for the youth discount.")
elif (18<=age<60):
    print("No discount available.")
# Out:
# No discount available.
