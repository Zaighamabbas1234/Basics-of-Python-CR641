# %%
# Lamada:

# %%
# Special type of the function.

# %%
# Lamada is the ananonyms function in which there is no name.

# %%
# The expression and the code in one line.

# %%
# The parameter is also is in one line.

# %%
# It can  be used with other functions.

# %%
# It is used with the filter , map , reduce.
