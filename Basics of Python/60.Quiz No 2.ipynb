# %%
# Quiz No 2:-

# %%
# Write a python program to print the length of a string?

# %%
# Sloution:-

# %%
str = "This is spartaaaa."

# %%
print(str)
# Out:
# This is spartaaaa.

# %%
print(len(str))
# Out:
# 18
