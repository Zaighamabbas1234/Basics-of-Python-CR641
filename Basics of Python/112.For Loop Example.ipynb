# %%
list = ["Mangeo,Apple,Grapes,Orange"]

# %%
for i in list:
    print(i)
# Out:
# Mangeo,Apple,Grapes,Orange

# %%
# Again Same Example:-

# %%
list = ["Mangeo","Apple","Grapes","Orange"]

# %%
for i in list:
    print(i)
# Out:
# Mangeo
# Apple
# Grapes
# Orange
