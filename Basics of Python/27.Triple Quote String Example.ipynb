# %%
# Triple Quote:-

# %%
# Triple Quote String are used for the multi line string.
# Double Line String.
# Triple Line String.

# %%
str = '''This is spartaa.
This is second spartaa.
This is third spartaa.'''

# %%
print(str)
# Out:
# This is spartaa.
# This is second spartaa.
# This is third spartaa.

# %%
# /n denotes for the next line or new line.
