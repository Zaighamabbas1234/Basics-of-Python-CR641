# %%
# Extracting The Key And  Values In Dictionary:-

# %%
# We can extracting the key and values in dictionary by using the folllowing function 
# Dictionary Identifier.key()
# Dictionary Identifier.values()

# %%
# dictionary = { "Apple":10, "Banana":20, "Gava":30, "Pineapple":40}
# Where "Apple" is the key and 10 is the value.
# Hence it is called key value pairs.
