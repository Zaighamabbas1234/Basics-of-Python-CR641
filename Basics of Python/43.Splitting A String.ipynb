# %%
# Splitting a string:-

# %%
# For splitting a string we can use the function ----.split("----").

# %%
# It adds '-----' on the right or left side and make it a block.

# %%
# ( "----" ) is the alphabet or word to be split.

# %%
# It takes only one parameter called split criteria.
