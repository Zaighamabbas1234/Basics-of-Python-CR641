# %%
tuple = (4,5,6,1.4,1.8,1.9,"Data,Data 1,Data 2",True,False)

# %%
print(tuple)
# Out:
# (4, 5, 6, 1.4, 1.8, 1.9, 'Data,Data 1,Data 2', True, False)

# %%
print(tuple*2)
# Out:
# (4, 5, 6, 1.4, 1.8, 1.9, 'Data,Data 1,Data 2', True, False, 4, 5, 6, 1.4, 1.8, 1.9, 'Data,Data 1,Data 2', True, False)
