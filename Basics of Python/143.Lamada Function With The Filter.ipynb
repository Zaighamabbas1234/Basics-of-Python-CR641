# %%
list_1 = [87,56,90,34,2,5,7,1,7,98]
print(list_1)
# Out:
# [87, 56, 90, 34, 2, 5, 7, 1, 7, 98]

# %%
final_list = list(filter(lambda x: (x%2!=0) , list_1))

# %%
final_list
# Out:
# [87, 5, 7, 1, 7]
