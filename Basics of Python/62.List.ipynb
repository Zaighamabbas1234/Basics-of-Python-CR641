# %%
# List:-

# %%
# List is an ordered collection of elements enclose within brackets [ ].

# %%
# Hetrogenous elements (Int, float, boolean , character) can saved in a list.

# %%
# List are mutable. ( Can be changed. )
