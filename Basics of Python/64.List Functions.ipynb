# %%
list_1 = [1,2,3,4,5,6,True,False,"Spartaaa",1.123,1.1]

# %%
list_2 = [11,12,13,14,15,16]

# %%
print(list_1,list_2)
# Out:
# [1, 2, 3, 4, 5, 6, True, False, 'Spartaaa', 1.123, 1.1] [11, 12, 13, 14, 15, 16]

# %%
# Already done in the previous lectures.

# %%
# Type of variable:-

# %%
print(type(list_2))
# Out:
# <class 'list'>

# %%
# Extracting individual element:-

# %%
print(list_1[2])
# Out:
# 3

# %%
# Extracting character:-

# %%
print(list_2[2:5])
# Exclusive function.
# Out:
# [13, 14, 15]

# %%
# Concatenating list:-

# %%
print(list_1+list_2)
# Out:
# [1, 2, 3, 4, 5, 6, True, False, 'Spartaaa', 1.123, 1.1, 11, 12, 13, 14, 15, 16]

# %%
# Repeating the List Elements:-

# %%
print(list_2*3)
# Out:
# [11, 12, 13, 14, 15, 16, 11, 12, 13, 14, 15, 16, 11, 12, 13, 14, 15, 16]
