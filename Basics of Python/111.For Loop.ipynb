# %%
# For Loop:-

# %%
# For loop is iterate over a sequence (tuple,list,dictionary,string).

# %%
# This is the syntex of the loop:-

# %%
# For (variable in sequence):
#      (Body of the For Loop.)
