# %%
# Number of occurance of a Substring:-

# %%
# The number of occurance of a substring can be find by using the function str.count( "-----" ).

# %%
# ( "----" ) is the word and alphabet to be find.
