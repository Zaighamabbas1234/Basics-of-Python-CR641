# %%
# Quiz No 1:-

# %%
# Declare variable name with your name as value.
# Declare variable age with your age as value.
# Print both variables.

# %%
# Solution:-

# %%
name = "Sam"

# %%
age = 24

# %%
print(name,age)
# Out:
# Sam 24

# %%
# Another solution:- (User Input.)

# %%
name = str(input("What is your name?"))

# %%
age = int(input ("What is your age?"))

# %%
print("My name is",name)
# Out:
# My name is Sam

# %%
print("My age is",age)
# Out:
# My age is 24
