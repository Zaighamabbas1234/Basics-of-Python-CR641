# %%
# Quiz No 3:-

# %%
# Declare varaibles a = 10 , b = 2.
# Calculate and print.
# Sum ( a + b ).
# Difference ( a - b ).
# Product ( a * b ).
# Quotient ( a / b ).

# %%
# Solution:-

# %%
a = 10

# %%
b = 2

# %%
print(a+b)
# Out:
# 12

# %%
print(a-b)
# Out:
# 8

# %%
print(a*b)
# Out:
# 20

# %%
print(a/b)
# Out:
# 5.0

# %%
print("a+b=",a+b)
# Out:
# a+b= 12

# %%
print("a-b=",a-b)
# Out:
# a-b= 8

# %%
print("a*b=",a*b)
# Out:
# a*b= 20

# %%
print("a/b=",a/b)
# Out:
# a/b= 5.0
