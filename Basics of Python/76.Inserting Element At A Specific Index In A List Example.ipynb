# %%
list = [1,2,3,4,5,6,True,False,"Spartaaa",1.123,1.1]

# %%
print(list)
# Out:
# [1, 2, 3, 4, 5, 6, True, False, 'Spartaaa', 1.123, 1.1]

# %%
list.insert(8,4) # The index of the other list become ( i+1 ).

# %%
print(list)
# Out:
# [1, 2, 3, 4, 5, 6, True, False, 4, 'Spartaaa', 1.123, 1.1]
