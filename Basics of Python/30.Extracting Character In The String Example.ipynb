# %%
str = 'This is spartaa.'

# %%
print(str)
# Out:
# This is spartaa.

# %%
# For extracting characters in the string use the colon ( : ).

# %%
# Left all the process reamin the same. 
# Semicolon is used  str[a:b].

# %%
str[5:10]
# Out:
# 'is sp'

# %%
# Its starts from 0 hance the 5 is ( i ) character.
# The 10 is the ( a ) character.
# A little bit confusing ????

# %%
# Solution:-

# %%
# It is always the [ a:b+1 ]
# Mean [ 5:10+1 ]
# Hence [ 5:11 ]

# %%
# Real Logic:-
# In Python the last value is not inclusive its exculsive.
# To make is inclusive then we use the n+1.

# %%
str[ 5:11 ]
# Out:
# 'is spa'
