# %%
dictionary_1 = {'Apple':2,'Banana':4,'Gava':5,'Pineapple':6}

# %%
print(dictionary_1)
# Out:
# {'Apple': 2, 'Banana': 4, 'Gava': 5, 'Pineapple': 6}

# %%
if dictionary_1['Apple'] == 2:
    dictionary_1['Apple'] = dictionary_1['Apple'] + 100
    print("This is the corrected value.")
else:
    print("This is not the corrected value.")
# Out:
# This is the corrected value.

# %%
print(dictionary_1)
# Out:
# {'Apple': 102, 'Banana': 4, 'Gava': 5, 'Pineapple': 6}
