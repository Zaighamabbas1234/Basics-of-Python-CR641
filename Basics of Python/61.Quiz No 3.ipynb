# %%
# Quiz No 3:-

# %%
# Write a python program to find the index of an element in a tuple?

# %%
# Solution:-

# %%
tuple = ( "This is sparta",1,2,3,4,5,6,7,8,True,False)

# %%
print(tuple)
# Out:
# ('This is sparta', 1, 2, 3, 4, 5, 6, 7, 8, True, False)

# %%
print(tuple.index(1)) 
# Use the Function [ tuple.index() ]
# Out:
# 1
