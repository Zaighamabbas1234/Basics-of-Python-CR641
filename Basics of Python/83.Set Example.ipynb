# %%
set ={"Set",False,"Data",1,2,3,4}

# %%
print(set)
# Out:
# {False, 1, 2, 3, 4, 'Data', 'Set'}

# %%
# Another Example:-

# %%
set_1 = {1,2,3,3,4,4,True,False,"Data","Data"}
# Do not print the repeat elements.

# %%
print(set_1)
# Out:
# {False, 1, 2, 3, 4, 'Data'}
